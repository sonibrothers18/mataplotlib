# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# # Histogram Plot -->

# %%
x = np.random.randint(10,60,50) # generates 50 random numbers between 10 and 60(exclusive) 
print(x)
# Out:
# [17 56 58 55 36 12 51 44 45 51 55 13 57 50 54 59 31 38 42 55 12 36 31 25
#  26 32 23 17 12 39 58 19 42 58 58 13 25 34 22 42 28 46 14 30 39 22 31 20
#  21 28]

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers)
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, orientation="horizontal")
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b") # change color to red and border to blue
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

l = [10,20,30,40,50,60]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", bins=l) # bins are used for grouping the range together
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", cumulative=-1) # cumulative used for ascending & descending order
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", bottom=20) # bottom changes the y axis value to 20 from 0
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

l = [10,20,30,40,50,60]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", bins=l, align="left") # align left means mid, mid means left
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", histtype="step") # type of histogram
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", histtype="stepfilled") # type of histogram
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", rwidth=0.8) # change the width of bars
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", log=True) # table is converted into log form
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b", label="pyhon")
plt.legend()
plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b")

plt.axvline(38, color="g", label="seperationLine") # seperate the graph by a green line and 38 will tell where line should drawn
plt.legend()

plt.show()

# %%
numbers = [26, 20, 34, 21, 50, 43, 14, 37, 56, 44, 14, 13, 19, 28, 35, 27, 42, 12, 27, 30, 19, 10, 58, 27, 38,
           26, 24, 59, 38, 20, 25, 27, 33, 13, 30, 43, 30, 23, 47, 47, 39, 11, 54, 34, 17, 22, 35, 28,
           14, 18]

plt.title("Histogram")
plt.xlabel("python")
plt.ylabel("No.")

plt.hist(numbers, color="r", edgecolor="b")

plt.grid() # use to show the grid lines in the graph

plt.show()
