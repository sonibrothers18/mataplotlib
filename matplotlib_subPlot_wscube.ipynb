# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Sub Plot -->

# %%
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x, y)
plt.show()

# %%
x1 = [10,20,30,40]

plt.pie(x)
plt.show()

# %%
x2 = ["a", "s", "d", "f"]
y2 = [10,20,30,40]

plt.bar(x2, y2)
plt.show()

# %%
# line graph
x = [1,2,3,4]
y = [1,2,3,4]

plt.subplot(2,2,1)
plt.plot(x, y)

# dot pie graph
plt.subplot(2,2,2)
plt.pie([1])

# pie graph
x1 = [10,20,30,40]

plt.subplot(2,2,3)
plt.pie(x)

# bar graph
x2 = ["a", "s", "d", "f"]
y2 = [10,20,30,40]

plt.subplot(2,2,4)
plt.bar(x2, y2)

plt.show()
